# %%
from IPython.display import Image
Image(filename=r'EV.jpeg')

# %%
import pandas as pd

# %%
df_electric=pd.read_csv('Electric_Vehicle_Population_Data.csv')

# %%
df_electric.head(-5)
# Out:
#         VIN (1-10)    County               City State  Postal Code  \
# 0       2C4RC1N71H    Kitsap          Bremerton    WA      98311.0
# 1       2C4RC1N7XL   Stevens           Colville    WA      99114.0
# 2       KNDC3DLCXN    Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA0J    Kitsap  Bainbridge Island    WA      98110.0
# 4       1N4AZ1CP7J  Thurston           Tumwater    WA      98501.0
# ...            ...       ...                ...   ...          ...
# 159457  WMW13DJ02N    Pierce         Gig Harbor    WA      98335.0
# 159458  WVGUNPE25M    Pierce           Fircrest    WA      98466.0
# 159459  1G1RA6S5XJ      King           Bellevue    WA      98006.0
# 159460  2C4RC1S72P    Benton          Kennewick    WA      99338.0
# 159461  7SAYGDEF4P  Thurston            Olympia    WA      98516.0
#
#         Model Year        Make     Model  \
# 0             2017    CHRYSLER  PACIFICA
# 1             2020    CHRYSLER  PACIFICA
# ...

# %%
df_electric.describe()
# Out:
#          Postal Code     Model Year  Electric Range     Base MSRP  \
# count  159463.000000  159467.000000   159467.000000  159467.00000
# mean    98170.373635    2020.192510       64.283319    1227.63716
# std      2453.354932       3.010564       94.634277    8930.03468
# min      1730.000000    1997.000000        0.000000       0.00000
# 25%     98052.000000    2018.000000        0.000000       0.00000
# 50%     98122.000000    2021.000000       14.000000       0.00000
# 75%     98370.000000    2023.000000       84.000000       0.00000
# max     99577.000000    2024.000000      337.000000  845000.00000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         159106.000000    1.594670e+05       1.594630e+05
# mean              29.261675    2.140242e+08       5.297287e+10
# std               14.843878    7.959275e+07       1.621526e+09
# min                1.000000    4.385000e+03       1.081042e+09
# ...

# %%
df_electric.shape
# Out:
# (159467, 17)

# %%
df_electric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159467 entries, 0 to 159466
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         159467 non-null  object
#  1   County                                             159463 non-null  object
#  2   City                                               159463 non-null  object
#  3   State                                              159467 non-null  object
#  4   Postal Code                                        159463 non-null  float64
#  5   Model Year                                         159467 non-null  int64
#  6   Make                                               159467 non-null  object
#  7   Model                                              159467 non-null  object
# ...

# %%
label = df_electric[['Clean Alternative Fuel Vehicle (CAFV) Eligibility']]
label.head()
# Out:
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility
# 0            Clean Alternative Fuel Vehicle Eligible
# 1            Clean Alternative Fuel Vehicle Eligible
# 2  Eligibility unknown as battery range has not b...
# 3            Clean Alternative Fuel Vehicle Eligible
# 4            Clean Alternative Fuel Vehicle Eligible

# %%
df_new = df_electric.drop(['Clean Alternative Fuel Vehicle (CAFV) Eligibility'],axis = 1)

# %%
df_new.head()
# Out:
#    VIN (1-10)    County               City State  Postal Code  Model Year  \
# 0  2C4RC1N71H    Kitsap          Bremerton    WA      98311.0        2017
# 1  2C4RC1N7XL   Stevens           Colville    WA      99114.0        2020
# 2  KNDC3DLCXN    Yakima             Yakima    WA      98908.0        2022
# 3  5YJ3E1EA0J    Kitsap  Bainbridge Island    WA      98110.0        2018
# 4  1N4AZ1CP7J  Thurston           Tumwater    WA      98501.0        2018
#
#        Make     Model                   Electric Vehicle Type  Electric Range  \
# 0  CHRYSLER  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)              33
# 1  CHRYSLER  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)              32
# 2       KIA       EV6          Battery Electric Vehicle (BEV)               0
# 3     TESLA   MODEL 3          Battery Electric Vehicle (BEV)             215
# 4    NISSAN      LEAF          Battery Electric Vehicle (BEV)             151
#
# ...

# %%
X = df_new
y = label

# %%
y.value_counts()
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Eligibility unknown as battery range has not been researched    77195
# Clean Alternative Fuel Vehicle Eligible                         63824
# Not eligible due to low battery range                           18448
# dtype: int64

# %%
print(X)
# Out:
#         VIN (1-10)    County               City State  Postal Code  \
# 0       2C4RC1N71H    Kitsap          Bremerton    WA      98311.0
# 1       2C4RC1N7XL   Stevens           Colville    WA      99114.0
# 2       KNDC3DLCXN    Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA0J    Kitsap  Bainbridge Island    WA      98110.0
# 4       1N4AZ1CP7J  Thurston           Tumwater    WA      98501.0
# ...            ...       ...                ...   ...          ...
# 159462  KM8JBDA2XP  Skamania          Underwood    WA      98651.0
# 159463  1G1FZ6S02M    Skagit                Bow    WA      98232.0
# 159464  YV4H60CX2P      King          Sammamish    WA      98029.0
# 159465  5YJ3E1EA7K   Whatcom         Bellingham    WA      98225.0
# 159466  7SAYGDEF6N    Island      Camano Island    WA      98282.0
#
#         Model Year       Make     Model  \
# 0             2017   CHRYSLER  PACIFICA
# 1             2020   CHRYSLER  PACIFICA
# ...

# %%
print(y)
# Out:
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility
# 0                 Clean Alternative Fuel Vehicle Eligible
# 1                 Clean Alternative Fuel Vehicle Eligible
# 2       Eligibility unknown as battery range has not b...
# 3                 Clean Alternative Fuel Vehicle Eligible
# 4                 Clean Alternative Fuel Vehicle Eligible
# ...                                                   ...
# 159462            Clean Alternative Fuel Vehicle Eligible
# 159463  Eligibility unknown as battery range has not b...
# 159464            Clean Alternative Fuel Vehicle Eligible
# 159465            Clean Alternative Fuel Vehicle Eligible
# 159466  Eligibility unknown as battery range has not b...
#
# [159467 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 38)

# %%
print('Total number of rows and columns for the complete dataset: ',X.shape, y.shape)

print('Number of rows and columns after splitting dataset: ',X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# Total number of rows and columns for the complete dataset:  (159467, 16) (159467, 1)
# Number of rows and columns after splitting dataset:  (127573, 16) (31894, 16) (127573, 1) (31894, 1)
